# %%
## Imports 

import pandas as pd
import lyricsgenius
import json


## Load Data ---- Need any number of Artists with their genre to look up their songs in genius 
artistdata = pd.read_csv("SampleArtistGenreData.csv")


## Initialize Data Frame
columns = ["artist", "genre", "song", "lyrics"]
df = pd.DataFrame(columns = columns)
data1 = []
dict1 = {}



### Util Function
def sanitize_filename(f):
    keepchars = (" ", ".", "_")
    return "".join(c for c in f if c.isalnum() or c in keepchars).rstrip()

# %%
# Out:
#               Artist        Genre
# 0              Drake          Rap
# 1  The Kings of Leon         Rock
# 2              Adele          Pop
# 3            Outkast  Hip-Hop/R&B
# 4         Luke Bryan      Country

# %%
### Input Genius API Key
key = "F4CU3dy2HaEawvSIDc7ISDsJP3RbHBuCGYyynmw03-XLEnYplx4zHjNiljNlRwrh"



### For every artist in data look up 5 of their songs in the genius API and save in DF
for y in artistdata.iterrows():
    artist = y[1][0]
    genre = y[1][1]
    n = y[0]
    print(n)
    genius = lyricsgenius.Genius(key)
    artistsearch = genius.search_artist(artist, sort="popularity", max_songs=1)
    artistsearch.save_lyrics(filename = artist+".json")
    
    filename = artist+".json"
    filename = sanitize_filename(filename)
    
    
    with open(filename) as json_file:
        data = json.load(json_file)
    
    for x in data["songs"]:
        
        song = x["title"]
        lyrics = x["lyrics"]
        lyrics = lyrics.split("\n")
        values = [artist, genre, song, lyrics]
        
        zipped = zip(columns, values)
        dict1 = dict(zipped)
        data1.append(dict1)

df1 = pd.DataFrame(data1, columns = columns)
# Out:
# 0
# Searching for songs by Drake...
#
# Song 1: "God’s Plan"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Wrote `Drake.json`
# 1
# Searching for songs by The Kings of Leon...
#
# Changing artist name to 'Original Broadway Cast of The Lion King'
# Song 1: "Circle of Life (Broadway Version)"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Wrote `The Kings of Leon.json`
# 2
# Searching for songs by Adele...
#
# Song 1: "Hello"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Wrote `Adele.json`
# 3
# Searching for songs by Outkast...
#
# Changing artist name to 'OutKast'
# Song 1: "Hey Ya!"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Wrote `Outkast.json`
# 4
# Searching for songs by Luke Bryan...
#
# Song 1: "Most People Are Good"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.
# Wrote `Luke Bryan.json`

# %%
df1
# Out:
#               artist        genre                               song  \
# 0              Drake          Rap                         God’s Plan
# 1  The Kings of Leon         Rock  Circle of Life (Broadway Version)
# 2              Adele          Pop                              Hello
# 3            Outkast  Hip-Hop/R&B                            Hey Ya!
# 4         Luke Bryan      Country               Most People Are Good
#
#                                               lyrics
# 0  [[Intro], And they wishin' and wishin' and wis...
# 1  [[RAFIKI & ENSEMBLE], Nants ingonyama bagithi ...
# 2  [[Verse 1], Hello, it's me, I was wondering if...
# 3  [[Intro: André 3000], 1, 2, 3, uh!, , [Verse 1...
# 4  [[Verse 1], I believe kids oughta stay kids as...

# %%
## Clean up df and write to csv

list1 = []
list2 = []
for x in df1["lyrics"]:
    list1 = []
    for y in x:
        if y != "":
            list1.append(y)
    list2.append(list1)
    
df1["editedlyrics"] = list2
df1.to_csv("LyricsData.csv", encoding='utf-8-sig')

# %%
df1
# Out:
#               artist        genre                               song  \
# 0              Drake          Rap                         God’s Plan
# 1  The Kings of Leon         Rock  Circle of Life (Broadway Version)
# 2              Adele          Pop                              Hello
# 3            Outkast  Hip-Hop/R&B                            Hey Ya!
# 4         Luke Bryan      Country               Most People Are Good
#
#                                               lyrics  \
# 0  [[Intro], And they wishin' and wishin' and wis...
# 1  [[RAFIKI & ENSEMBLE], Nants ingonyama bagithi ...
# 2  [[Verse 1], Hello, it's me, I was wondering if...
# 3  [[Intro: André 3000], 1, 2, 3, uh!, , [Verse 1...
# 4  [[Verse 1], I believe kids oughta stay kids as...
#
#                                         editedlyrics
# 0  [[Intro], And they wishin' and wishin' and wis...
# 1  [[RAFIKI & ENSEMBLE], Nants ingonyama bagithi ...
# 2  [[Verse 1], Hello, it's me, I was wondering if...
# 3  [[Intro: André 3000], 1, 2, 3, uh!, [Verse 1: ...
# 4  [[Verse 1], I believe kids oughta stay kids as...
